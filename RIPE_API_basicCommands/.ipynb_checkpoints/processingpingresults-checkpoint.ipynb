# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.float_format = '{:20,.2f}'.format

# %%
df = pd.read_json("/Users/ritaingabire/Documents/RESTAPIMeasurements/RIPE-Atlas-measurement-47800129.json")
df['prb_id'].describe()
# Out:
# count                  49.00
# mean              612,492.31
# std               476,280.94
# min                20,757.00
# 25%                53,229.00
# 50%             1,002,914.00
# 75%             1,004,102.00
# max             1,004,991.00
# Name: prb_id, dtype: float64

# %%
df
# Out:
#       fw   mver  lts     dst_name  af     dst_addr         src_addr proto  \
# 0   5080  2.6.2   32  52.46.64.63   4  52.46.64.63    192.168.1.179  ICMP
# 1   5030  2.4.0    3  52.46.64.63   4  52.46.64.63   172.24.234.195  ICMP
# 2   5040  2.4.1   42  52.46.64.63   4  52.46.64.63    10.18.246.209  ICMP
# 3   5040  2.4.1    5  52.46.64.63   4  52.46.64.63      10.109.0.30  ICMP
# 4   5040  2.4.1    9  52.46.64.63   4  52.46.64.63      192.168.1.3  ICMP
# 5   5040  2.4.1   23  52.46.64.63   4  52.46.64.63  192.168.168.209  ICMP
# 6   5080  2.6.2    8  52.46.64.63   4  52.46.64.63     172.31.6.130  ICMP
# 7   5080  2.6.2   15  52.46.64.63   4  52.46.64.63   192.168.250.65  ICMP
# 8   5080  2.6.2    7  52.46.64.63   4  52.46.64.63    192.168.0.100  ICMP
# 9   5080  2.6.2   24  52.46.64.63   4  52.46.64.63     192.168.1.38  ICMP
# 10  5080  2.6.2    4  52.46.64.63   4  52.46.64.63    192.168.1.179  ICMP
# 11  5030  2.4.0    9  52.46.64.63   4  52.46.64.63   172.24.234.195  ICMP
# ...

# %%
nprb_id = []

for value in df["prb_id"]:
    if value == 1004991:
        nprb_id.append('es1')
    if value == 53229:
        nprb_id.append('es2')
    if value == 1004997:
        nprb_id.append("pt1")
    if value == 1004102:
        nprb_id.append("pt2")
    if value == 20757:
        nprb_id.append("es3")
    if value ==1003454:
        nprb_id.append("nl1")
    if value == 1003158:
        nprb_id.append("nl2")
    if value == 1003747:
        nprb_id.append("nl3")
    if value == 1004200:
        nprb_id.append("es4")
    if value == 51381:
        nprb_id.append("ug1")
    if value == 54470:
        nprb_id.append("us1")
    if value == 1002914:
        nprb_id.append("us2")
        
        
df["nprb_id"] = nprb_id
df
# Out:
#       fw   mver  lts     dst_name  af     dst_addr         src_addr proto  \
# 0   5080  2.6.2   32  52.46.64.63   4  52.46.64.63    192.168.1.179  ICMP
# 1   5030  2.4.0    3  52.46.64.63   4  52.46.64.63   172.24.234.195  ICMP
# 2   5040  2.4.1   42  52.46.64.63   4  52.46.64.63    10.18.246.209  ICMP
# 3   5040  2.4.1    5  52.46.64.63   4  52.46.64.63      10.109.0.30  ICMP
# 4   5040  2.4.1    9  52.46.64.63   4  52.46.64.63      192.168.1.3  ICMP
# 5   5040  2.4.1   23  52.46.64.63   4  52.46.64.63  192.168.168.209  ICMP
# 6   5080  2.6.2    8  52.46.64.63   4  52.46.64.63     172.31.6.130  ICMP
# 7   5080  2.6.2   15  52.46.64.63   4  52.46.64.63   192.168.250.65  ICMP
# 8   5080  2.6.2    7  52.46.64.63   4  52.46.64.63    192.168.0.100  ICMP
# 9   5080  2.6.2   24  52.46.64.63   4  52.46.64.63     192.168.1.38  ICMP
# 10  5080  2.6.2    4  52.46.64.63   4  52.46.64.63    192.168.1.179  ICMP
# 11  5030  2.4.0    9  52.46.64.63   4  52.46.64.63   172.24.234.195  ICMP
# ...

# %%
plt.scatter(df['nprb_id'], df['avg'])
plt.title('probe ids against rtt')
# Out:
# Text(0.5, 1.0, 'probe ids against rtt')
