# %%
# Importing the necessary libraries 
# Installing prophet on macos - https://gist.github.com/thewisenerd/52f937d01b06287ccf21a05a118e74ad
# pandas version pd.__version__

import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# Making the plots standard 
# %matplotlib inline
plt.rcParams["figure.figsize"] = [16, 5]
plt.rcParams['legend.fontsize'] = 15

# %%
# Putting the measurement files in a list for easy processing 
pfiles = ["./data/RIPE-Atlas-measurement-48819905.json","./data/RIPE-Atlas-measurement-48819907.json","./data/RIPE-Atlas-measurement-48819909.json","./data/RIPE-Atlas-measurement-48819911.json","./data/RIPE-Atlas-measurement-48819913.json"]

# %%
# Merging the ping measurement files 
# https://stackoverflow.com/questions/57422734/how-to-merge-multiple-json-files-into-one-file-in-python

def merge_JsonFiles(filename):
    result = list()
    for f1 in filename:
        with open(f1, 'r') as infile:
            result.extend(json.load(infile))

    with open('mergedJson.json', 'w') as output_file:
        json.dump(result, output_file)

merge_JsonFiles(pfiles)

# %%
# Putting the merged files into a dataframe - preparing the data for forecasting
df = pd.read_json("./mergedJson.json")
df
# Out:
#          fw   mver  lts      dst_name  af      dst_addr         src_addr  \
# 0      5040  2.4.1   14   52.46.72.50   4   52.46.72.50    10.18.246.209
# 1      5040  2.4.1   20   52.46.72.50   4   52.46.72.50      10.109.0.30
# 2      5080  2.6.2   96   52.46.72.50   4   52.46.72.50   192.168.250.65
# 3      5080  2.6.2   12   52.46.72.50   4   52.46.72.50     192.168.1.38
# 4      5080  2.6.2   33   52.46.72.50   4   52.46.72.50    192.168.0.101
# ...     ...    ...  ...           ...  ..           ...              ...
# 28170  5040  2.4.1    3  52.46.200.93   4  52.46.200.93      192.168.1.3
# 28171  5040  2.4.1    2  52.46.200.93   4  52.46.200.93  192.168.168.209
# 28172  5080  2.6.2   67  52.46.200.93   4  52.46.200.93     192.168.1.38
# 28173  5040  2.4.1   49  52.46.200.93   4  52.46.200.93    10.18.246.209
# 28174  5080  2.6.2   48  52.46.200.93   4  52.46.200.93     172.31.6.130
#
#       proto    ttl  size  ...         avg    msm_id   prb_id  \
# 0      ICMP  234.0    64  ...   14.612530  48819905  1003454
# 1      ICMP  233.0    64  ...   24.125096  48819905  1003747
# 2      ICMP  233.0    64  ...   22.542065  48819905    20757
# 3      ICMP  234.0    64  ...   26.183208  48819905    53229
# 4      ICMP  232.0    64  ...  171.458986  48819905    51381
# ...     ...    ...   ...  ...         ...       ...      ...
# 28170  ICMP  235.0    64  ...   68.508421  48819913  1004102
# 28171  ICMP  221.0    64  ...   70.749029  48819913  1004200
# 28172  ICMP  220.0    64  ...   56.019584  48819913    53229
# 28173  ICMP  231.0    64  ...   19.059942  48819913  1003454
# 28174  ICMP  224.0    64  ...   48.755808  48819913  1004991
#
#                 timestamp  msm_name            from  type  group_id  step  \
# 0     2023-01-16 10:13:25      Ping      51.15.99.8  ping  48819905   300
# 1     2023-01-16 10:13:23      Ping   45.137.88.145  ping  48819905   300
# 2     2023-01-16 10:13:11      Ping  82.116.160.225  ping  48819905   300
# 3     2023-01-16 10:13:39      Ping   83.54.157.101  ping  48819905   300
# 4     2023-01-16 10:14:34      Ping      102.34.0.4  ping  48819905   300
# ...                   ...       ...             ...   ...       ...   ...
# 28170 2023-01-18 09:09:59      Ping  149.90.236.149  ping  48819913   300
# 28171 2023-01-18 09:09:51      Ping    88.24.68.105  ping  48819913   300
# 28172 2023-01-18 09:09:21      Ping   83.54.157.101  ping  48819913   300
# 28173 2023-01-18 09:10:09      Ping      51.15.99.8  ping  48819913   300
# 28174 2023-01-18 09:10:43      Ping    18.100.6.236  ping  48819913   300
#
#       stored_timestamp
# 0           1673864050
# 1           1673864114
# 2           1673864089
# 3           1673864090
# 4           1673864205
# ...                ...
# 28170       1674033077
# 28171       1674033051
# 28172       1674033081
# 28173       1674033100
# 28174       1674033177
#
# [28175 rows x 26 columns]

# %%
# Cleaning the data 

# Checking the negative values - possible time out ???
df_test = df[df['avg']<0]
df_test.groupby(['prb_id','dst_addr']).count()
# Out:
# Empty DataFrame
# Columns: [fw, mver, lts, dst_name, af, src_addr, proto, ttl, size, result, dup, rcvd, sent, min, max, avg, msm_id, timestamp, msm_name, from, type, group_id, step, stored_timestamp]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Change them to NaN
df['avg'].replace(-1.0, np.nan, inplace=True)

# Checking for null values in each column
df_null = df['avg'].isnull().sum()
df_null
# Out:
# 243

# %%
# Remove Null values 
df = df.dropna(how='any',axis=0) 
df.shape
# Out:
# (27932, 26)

# %%
# Renaming the probe_id column for easy plotting 
nprb_id = []

for value in df["prb_id"]:
    if value == 1004991:
        nprb_id.append('es1')
    if value == 53229:
        nprb_id.append('es2')
    if value == 1004997:
        nprb_id.append("pt1")
    if value == 1004102:
        nprb_id.append("pt2")
    if value == 20757:
        nprb_id.append("es3")
    if value ==1003454:
        nprb_id.append("nl1")
    if value == 1003158:
        nprb_id.append("nl2")
    if value == 1003747:
        nprb_id.append("nl3")
    if value == 1004200:
        nprb_id.append("es4")
    if value == 51381:
        nprb_id.append("ug1")
    if value == 54470:
        nprb_id.append("us1")
    if value == 1002914:
        nprb_id.append("us2")
        
        
df["nprb_id"] = nprb_id

dest_id = []
for value in df["dst_name"]:
    if value == '52.46.200.93':
        dest_id.append('euN1')
    if value == '67.220.226.67':
        dest_id.append('euW1')
    if value == '52.94.56.52':
        dest_id.append("euW2")
    if value == '52.46.72.50':
        dest_id.append("euW3")
    if value == '54.239.55.167':
        dest_id.append("euC1")

        
df["dst_id"] = dest_id
# Out:
# C:\Users\anton\AppData\Local\Temp\ipykernel_20780\3329890090.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nprb_id"] = nprb_id
# C:\Users\anton\AppData\Local\Temp\ipykernel_20780\3329890090.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["dst_id"] = dest_id

# %%
country_name = []

for value in df["nprb_id"]:
    if (value == 'es1') or (value == 'es2') or(value == 'es3') or( value == 'es4'):
        country_name.append('Spain')
    if(value == 'nl1') or (value == 'nl2')or (value == 'nl3'):
        country_name.append('Netherlands')
    if(value == 'pt1') or (value == 'pt2'):
        country_name.append('Portugal')
    if(value == 'us1') or (value == 'us2'):
        country_name.append('USA')
    if(value == 'ug1'):
        country_name.append('Uganda')
        
df['country_name'] = country_name
# Out:
# C:\Users\anton\AppData\Local\Temp\ipykernel_20780\534829545.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country_name'] = country_name

# %%
# Changing the time column from epoch to date time format for time series processing 
new_timestamp = []

for i in df['stored_timestamp']:
    my_datetime = datetime.fromtimestamp(i)
    new_timestamp.append(my_datetime)

df2 = df.copy()
df2['new_time'] = new_timestamp

# %%
#  Grouping results by probe_id then destination 
df2.groupby(['nprb_id','dst_id']).count()
# Out:
#                  fw  mver  lts  dst_name   af  dst_addr  src_addr  proto  ttl  \
# nprb_id dst_id
# es1     euC1    564   564  564       564  564       564       564    564  564
#         euN1    564   564  564       564  564       564       564    564  564
#         euW1    564   564  564       564  564       564       564    564  564
#         euW2    564   564  564       564  564       564       564    564  564
#         euW3    564   564  564       564  564       564       564    564  564
# es2     euC1    564   564  564       564  564       564       564    564  564
#         euN1    564   564  564       564  564       564       564    564  564
#         euW1    564   564  564       564  564       564       564    564  564
#         euW2    564   564  564       564  564       564       564    564  564
#         euW3    564   564  564       564  564       564       564    564  564
# es3     euC1    564   564  564       564  564       564       564    564  564
#         euN1    564   564  564       564  564       564       564    564  564
#         euW1    564   564  564       564  564       564       564    564  564
#         euW2    564   564  564       564  564       564       564    564  564
#         euW3    564   564  564       564  564       564       564    564  564
# es4     euC1    564   564  564       564  564       564       564    564  564
#         euN1    564   564  564       564  564       564       564    564  564
#         euW1    564   564  564       564  564       564       564    564  564
#         euW2    564   564  564       564  564       564       564    564  564
#         euW3    564   564  564       564  564       564       564    564  564
# nl1     euC1    564   564  564       564  564       564       564    564  564
#         euN1    564   564  564       564  564       564       564    564  564
#         euW1    564   564  564       564  564       564       564    564  564
#         euW2    564   564  564       564  564       564       564    564  564
#         euW3    564   564  564       564  564       564       564    564  564
# nl3     euC1    564   564  564       564  564       564       564    564  564
#         euN1    564   564  564       564  564       564       564    564  564
#         euW1    564   564  564       564  564       564       564    564  564
#         euW2    564   564  564       564  564       564       564    564  564
#         euW3    564   564  564       564  564       564       564    564  564
# pt2     euC1    555   555  555       555  555       555       555    555  555
#         euN1    556   556  556       556  556       556       556    556  556
#         euW1    555   555  555       555  555       555       555    555  555
#         euW2    555   555  555       555  555       555       555    555  555
#         euW3    556   556  556       556  556       556       556    556  556
# ug1     euC1    521   521  521       521  521       521       521    521  521
#         euN1    520   520  520       520  520       520       520    520  520
#         euW1    520   520  520       520  520       520       520    520  520
#         euW2    521   521  521       521  521       521       521    521  521
#         euW3    521   521  521       521  521       521       521    521  521
# us1     euC1    563   563  563       563  563       563       563    563  563
#         euN1    563   563  563       563  563       563       563    563  563
#         euW1    562   562  562       562  562       562       562    562  562
#         euW2    562   562  562       562  562       562       562    562  562
#         euW3    562   562  562       562  562       562       562    562  562
# us2     euC1    564   564  564       564  564       564       564    564  564
#         euN1    564   564  564       564  564       564       564    564  564
#         euW1    564   564  564       564  564       564       564    564  564
#         euW2    564   564  564       564  564       564       564    564  564
#         euW3    564   564  564       564  564       564       564    564  564
#
#                 size  ...  prb_id  timestamp  msm_name  from  type  group_id  \
# nprb_id dst_id        ...
# es1     euC1     564  ...     564        564       564   564   564       564
#         euN1     564  ...     564        564       564   564   564       564
#         euW1     564  ...     564        564       564   564   564       564
#         euW2     564  ...     564        564       564   564   564       564
#         euW3     564  ...     564        564       564   564   564       564
# es2     euC1     564  ...     564        564       564   564   564       564
#         euN1     564  ...     564        564       564   564   564       564
#         euW1     564  ...     564        564       564   564   564       564
#         euW2     564  ...     564        564       564   564   564       564
#         euW3     564  ...     564        564       564   564   564       564
# es3     euC1     564  ...     564        564       564   564   564       564
#         euN1     564  ...     564        564       564   564   564       564
#         euW1     564  ...     564        564       564   564   564       564
#         euW2     564  ...     564        564       564   564   564       564
#         euW3     564  ...     564        564       564   564   564       564
# es4     euC1     564  ...     564        564       564   564   564       564
#         euN1     564  ...     564        564       564   564   564       564
#         euW1     564  ...     564        564       564   564   564       564
#         euW2     564  ...     564        564       564   564   564       564
#         euW3     564  ...     564        564       564   564   564       564
# nl1     euC1     564  ...     564        564       564   564   564       564
#         euN1     564  ...     564        564       564   564   564       564
#         euW1     564  ...     564        564       564   564   564       564
#         euW2     564  ...     564        564       564   564   564       564
#         euW3     564  ...     564        564       564   564   564       564
# nl3     euC1     564  ...     564        564       564   564   564       564
#         euN1     564  ...     564        564       564   564   564       564
#         euW1     564  ...     564        564       564   564   564       564
#         euW2     564  ...     564        564       564   564   564       564
#         euW3     564  ...     564        564       564   564   564       564
# pt2     euC1     555  ...     555        555       555   555   555       555
#         euN1     556  ...     556        556       556   556   556       556
#         euW1     555  ...     555        555       555   555   555       555
#         euW2     555  ...     555        555       555   555   555       555
#         euW3     556  ...     556        556       556   556   556       556
# ug1     euC1     521  ...     521        521       521   521   521       521
#         euN1     520  ...     520        520       520   520   520       520
#         euW1     520  ...     520        520       520   520   520       520
#         euW2     521  ...     521        521       521   521   521       521
#         euW3     521  ...     521        521       521   521   521       521
# us1     euC1     563  ...     563        563       563   563   563       563
#         euN1     563  ...     563        563       563   563   563       563
#         euW1     562  ...     562        562       562   562   562       562
#         euW2     562  ...     562        562       562   562   562       562
#         euW3     562  ...     562        562       562   562   562       562
# us2     euC1     564  ...     564        564       564   564   564       564
#         euN1     564  ...     564        564       564   564   564       564
#         euW1     564  ...     564        564       564   564   564       564
#         euW2     564  ...     564        564       564   564   564       564
#         euW3     564  ...     564        564       564   564   564       564
#
#                 step  stored_timestamp  country_name  new_time
# nprb_id dst_id
# es1     euC1     564               564           564       564
#         euN1     564               564           564       564
#         euW1     564               564           564       564
#         euW2     564               564           564       564
#         euW3     564               564           564       564
# es2     euC1     564               564           564       564
#         euN1     564               564           564       564
#         euW1     564               564           564       564
#         euW2     564               564           564       564
#         euW3     564               564           564       564
# es3     euC1     564               564           564       564
#         euN1     564               564           564       564
#         euW1     564               564           564       564
#         euW2     564               564           564       564
#         euW3     564               564           564       564
# es4     euC1     564               564           564       564
#         euN1     564               564           564       564
#         euW1     564               564           564       564
#         euW2     564               564           564       564
#         euW3     564               564           564       564
# nl1     euC1     564               564           564       564
#         euN1     564               564           564       564
#         euW1     564               564           564       564
#         euW2     564               564           564       564
#         euW3     564               564           564       564
# nl3     euC1     564               564           564       564
#         euN1     564               564           564       564
#         euW1     564               564           564       564
#         euW2     564               564           564       564
#         euW3     564               564           564       564
# pt2     euC1     555               555           555       555
#         euN1     556               556           556       556
#         euW1     555               555           555       555
#         euW2     555               555           555       555
#         euW3     556               556           556       556
# ug1     euC1     521               521           521       521
#         euN1     520               520           520       520
#         euW1     520               520           520       520
#         euW2     521               521           521       521
#         euW3     521               521           521       521
# us1     euC1     563               563           563       563
#         euN1     563               563           563       563
#         euW1     562               562           562       562
#         euW2     562               562           562       562
#         euW3     562               562           562       562
# us2     euC1     564               564           564       564
#         euN1     564               564           564       564
#         euW1     564               564           564       564
#         euW2     564               564           564       564
#         euW3     564               564           564       564
#
# [50 rows x 28 columns]

# %%
# Extracting the results of one probe and destination
dfprbdtn = df2[(df2['nprb_id'] == 'es1') & (df2['dst_id'] == "euN1")]

# Visualising the distribution of rtt 
plt.plot(dfprbdtn["new_time"],dfprbdtn["avg"])
plt.ylabel("round trip time(ms)")
plt.xlabel("DateTime")
plt.xticks(rotation=45)
plt.title("Round trip time Vs Time ")
# Out:
# Text(0.5, 1.0, 'Round trip time Vs Time ')

# %%
# Visualising the cumulative distribution of the whole population
# https://stackoverflow.com/questions/25577352/plotting-cdf-of-a-pandas-series-in-python
# https://www.youtube.com/watch?v=a7pi68qu8-g

stats_df = df.copy()

# Using numpy to plot histogram - get bins and edges first
c,e = np.histogram(stats_df['avg'])

#using the center of the bins for plotting 
b = (e[1:]+e[-1]/2)

#plot 
plt.scatter(b,c)

# %%
# Using matplotlib to plot histograms.
# Add density to normalise
c = plt.hist(stats_df['avg'],bins = 100,density = True)

# %%
stats_df['avg'].hist(cumulative=True, density=True, bins=100)
plt.show()

# %%
#checking cdf for each of the probes
probes = ['es1','es2','es3','es4','nl1','nl3','pt2','ug1','us1','us2']

for probe in probes:
    df_cdf = df2[(df2['nprb_id'] == probe)]
    axx = df_cdf['avg'].hist(cumulative=True, density=True, bins=100, alpha = 0.3)
axx.legend(probes)

# %%
#checking pdf for each of the probes
countries = df['country_name'].unique()

for country in countries:
    df_pdf = df[(df['country_name'] == country)]
    axx = df_pdf['avg'].hist(density=True, bins=100, alpha = 0.3)

axx.legend(countries)

# %%
#checking cdf for each of the destinations

dsts = df['dst_id'].unique()

for dst in dsts:
    df_cdf = df2[(df2['dst_id'] == dst)]
    axx = df_cdf['avg'].hist(cumulative=True, density=True, bins=100, alpha = 0.25)
axx.legend(dsts)
